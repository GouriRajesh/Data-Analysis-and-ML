# %% [markdown]
# <H2> Exploratory Data Analysis on Breast Cancer in Wisconsin </H2>

# %% [markdown]
# <h3> Design a model to predict whether the cancer is benign or malignant. </h3>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("breast-cancer-wisconsin.csv")
data
# Out:
#      id number  Clump Thickness  Uniformity of Cell Size  \
# 0      1000025                5                        1
# 1      1002945                5                        4
# 2      1015425                3                        1
# 3      1016277                6                        8
# 4      1017023                4                        1
# ..         ...              ...                      ...
# 694     776715                3                        1
# 695     841769                2                        1
# 696     888820                5                       10
# 697     897471                4                        8
# 698     897471                4                        8
#
#      Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                           1                  1                            2
# 1                           4                  5                            7
# ...

# %%
data.pop('id number')
data
# Out:
#      Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# 0                  5                        1                         1
# 1                  5                        4                         4
# 2                  3                        1                         1
# 3                  6                        8                         8
# 4                  4                        1                         1
# ..               ...                      ...                       ...
# 694                3                        1                         1
# 695                2                        1                         1
# 696                5                       10                        10
# 697                4                        8                         6
# 698                4                        8                         8
#
#      Marginal Adhesion  Single Epithelial Cell Size Bare Nuclei  \
# ...

# %%
data.isnull().sum()
# Out:
# Clump Thickness                0
# Uniformity of Cell Size        0
# Uniformity of Cell Shape       0
# Marginal Adhesion              0
# Single Epithelial Cell Size    0
# Bare Nuclei                    0
# Bland Chromatin                0
# Normal Nucleoli                0
# Mitoses                        0
# Class                          0
# dtype: int64

# %%
data = data.replace('?',np.NaN)

# %%
data = data.dropna()
data
# Out:
#      Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# 0                  5                        1                         1
# 1                  5                        4                         4
# 2                  3                        1                         1
# 3                  6                        8                         8
# 4                  4                        1                         1
# ..               ...                      ...                       ...
# 694                3                        1                         1
# 695                2                        1                         1
# 696                5                       10                        10
# 697                4                        8                         6
# 698                4                        8                         8
#
#      Marginal Adhesion  Single Epithelial Cell Size Bare Nuclei  \
# ...

# %%
data.dtypes
# Out:
# Clump Thickness                 int64
# Uniformity of Cell Size         int64
# Uniformity of Cell Shape        int64
# Marginal Adhesion               int64
# Single Epithelial Cell Size     int64
# Bare Nuclei                    object
# Bland Chromatin                 int64
# Normal Nucleoli                 int64
# Mitoses                         int64
# Class                           int64
# dtype: object

# %%
data['Bare Nuclei']
# Out:
# 0       1
# 1      10
# 2       2
# 3       4
# 4       1
#        ..
# 694     2
# 695     1
# 696     3
# 697     4
# 698     5
# Name: Bare Nuclei, Length: 683, dtype: object

# %%
data['Bare Nuclei'] = data['Bare Nuclei'].astype('int64')
data['Bare Nuclei']
# Out:
# 0       1
# 1      10
# 2       2
# 3       4
# 4       1
#        ..
# 694     2
# 695     1
# 696     3
# 697     4
# 698     5
# Name: Bare Nuclei, Length: 683, dtype: int64

# %%
data.dtypes
# Out:
# Clump Thickness                int64
# Uniformity of Cell Size        int64
# Uniformity of Cell Shape       int64
# Marginal Adhesion              int64
# Single Epithelial Cell Size    int64
# Bare Nuclei                    int64
# Bland Chromatin                int64
# Normal Nucleoli                int64
# Mitoses                        int64
# Class                          int64
# dtype: object

# %%
sns.pairplot(data,hue='Class')
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# ...

# %%
data_class = data.pop('Class')
data_class
# Out:
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
#       ..
# 694    2
# 695    2
# 696    4
# 697    4
# 698    4
# Name: Class, Length: 683, dtype: int64

# %%
data
# Out:
#      Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# 0                  5                        1                         1
# 1                  5                        4                         4
# 2                  3                        1                         1
# 3                  6                        8                         8
# 4                  4                        1                         1
# ..               ...                      ...                       ...
# 694                3                        1                         1
# 695                2                        1                         1
# 696                5                       10                        10
# 697                4                        8                         6
# 698                4                        8                         8
#
#      Marginal Adhesion  Single Epithelial Cell Size  Bare Nuclei  \
# ...

# %%
sns.pairplot(data)

# %%
from sklearn.model_selection import train_test_split

X = data
y = data_class

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

print(X_train.shape)
print(X_test.shape)
# Out:
# (546, 9)
# (137, 9)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.9708029197080292

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean Absolute Error: 0.058394160583941604

# %%
print('Max Error:', metrics.max_error(y_test, y_pred))
# Out:
# Max Error: 2

# %%
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
# Out:
# Mean Squared Error: 0.11678832116788321

# %%
df1 = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})  
df1
# Out:
#      Actual  Predicted
# 539       2          2
# 80        2          2
# 115       2          2
# 549       4          4
# 519       4          4
# ..      ...        ...
# 290       2          2
# 347       2          2
# 157       2          2
# 507       2          2
# 629       2          2
#
# [137 rows x 2 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics

ds = DecisionTreeClassifier()
ds.fit(X_train, y_train)
y_predi = ds.predict(X_test)


print(metrics.accuracy_score(y_test,y_predi))
# Out:
# 0.927007299270073

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_predi))
# Out:
# Mean Absolute Error: 0.145985401459854

# %%
print('Max Error:', metrics.max_error(y_test, y_predi))
# Out:
# Max Error: 2

# %%
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_predi))
# Out:
# Mean Squared Error: 0.291970802919708

# %%
df2 = pd.DataFrame({'Actual': y_test, 'Predicted': y_predi})  
df2
# Out:
#      Actual  Predicted
# 539       2          2
# 80        2          2
# 115       2          2
# 549       4          4
# 519       4          4
# ..      ...        ...
# 290       2          2
# 347       2          2
# 157       2          2
# 507       2          2
# 629       2          2
#
# [137 rows x 2 columns]
